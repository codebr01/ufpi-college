# %%
from skimage.io import imread
from matplotlib.pyplot import imshow

# class Conta:

#   _total_contas = 0

#   __slots__ = ['_titular', '_saldo']

#   def __init__(self, titular, saldo) -> None:
#     self._titular = titular
#     self._saldo = saldo

#   def get_saldo(self):
#     return self._saldo
  
#   def set_saldo(self, saldo):
#     self._saldo = saldo

#   def get_titular(self):
#     return self._titular
  
#   def set_titular(self, titular):
#     self._titular = titular

class Fotografia:
  def __init__(self, foto) -> None:
    self.foto = imread(foto)

  def mostrar_fotografia(self):
    imshow(self.foto)

  def prop_fotografia(self):
    return self.foto.shape()
  
foto = 'uzuiicon2.jpg'
fotografia = Fotografia(foto)

fotografia.mostrar_fotografia()

# %%
import os
import cv2
import numpy as np
from skimage import metrics

# %%
# Caminhos para as pastas de entrada (imagens) e saída (resultados)
input_folder = 'ultrassound\\cropped'
mask_folder = 'ultrassound\\masks'
output_folder = 'result2'

# %%
# Obter o caminho completo para as pastas
input_folder_full = os.path.join(os.getcwd(), input_folder)
mask_folder_full = os.path.join(os.getcwd(), mask_folder)
output_folder_full = os.path.join(os.getcwd(), output_folder)

# %%
# Verificar se as pastas existem
if not os.path.exists(input_folder_full) or not os.path.exists(mask_folder_full):
    print(f"As pastas de entrada '{input_folder_full}' ou '{mask_folder_full}' não foram encontradas.")
    exit()

# %%
# Criar a pasta de saída se não existir
os.makedirs(output_folder_full, exist_ok=True)

# %%
# Lista de arquivos na pasta de entrada
image_files = [f for f in os.listdir(input_folder_full) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

# %%
# Loop sobre todas as imagens na pasta de entrada
for image_file in image_files:
    # Construir o caminho completo da imagem de entrada
    image_path = os.path.join(input_folder_full, image_file)

    # Construir o caminho completo da máscara de referência
    mask_path = os.path.join(mask_folder_full, image_file)

    # Tente carregar a imagem e a máscara
    image = cv2.imread(image_path)
    mask_reference = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    # Verifique se a imagem e a máscara foram carregadas com sucesso
    if image is None or mask_reference is None:
        print(f'Erro ao carregar a imagem ou a máscara de referência: {image_path}')
        continue

    # Aplicar a segmentação (exemplo: binarização de Otsu)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, segmented_mask = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Salvar a máscara segmentada na pasta de saída
    output_mask_path = os.path.join(output_folder_full, f'segmented_{image_file}')
    cv2.imwrite(output_mask_path, segmented_mask)

    # Calcular a Dice coefficient
    dice_coefficient = (2 * np.logical_and(mask_reference.flatten(), segmented_mask.flatten()).sum()) / \
                   (mask_reference.flatten().sum() + segmented_mask.flatten().sum())

    # Calcular o Jaccard index (IoU)
    intersection = np.logical_and(mask_reference.flatten(), segmented_mask.flatten()).sum()
    union = np.logical_or(mask_reference.flatten(), segmented_mask.flatten()).sum()
    jaccard_index = intersection / union


    # Imprimir os resultados
    print(f'Imagem: {image_file}')
    print(f'Dice Coefficient: {dice_coefficient}')
    print(f'Jaccard Index (IoU): {jaccard_index}')
    print('---')
# Out:
# Imagem: 1100208028.bmp
# Dice Coefficient: 0.002955899541270205
# Jaccard Index (IoU): 0.6048200874341442
# ---
# Imagem: 1100209013.bmp
# Dice Coefficient: 0.00265140646058867
# Jaccard Index (IoU): 0.5106979860151573
# ---
# Imagem: 1100210009.bmp
# Dice Coefficient: 0.002135754269951868
# Jaccard Index (IoU): 0.3742090333842461
# ---
# Imagem: 1100210637.bmp
# Dice Coefficient: 0.0028504441991273723
# Jaccard Index (IoU): 0.570923180592992
# ---
# Imagem: 1100211010.bmp
# Dice Coefficient: 0.0018114777135473897
# Jaccard Index (IoU): 0.30032824318538603
# ---
# Imagem: 1100211015.bmp
# Dice Coefficient: 0.0025404421447802524
# Jaccard Index (IoU): 0.4790850863612907
# ---
# Imagem: 1100211016.bmp
# Dice Coefficient: 0.0021123174605774914
# Jaccard Index (IoU): 0.3685890564329784
# ---
# Imagem: 1100211017.bmp
# Dice Coefficient: 0.002772937479699162
# Jaccard Index (IoU): 0.5469089193015574
# ---
# Imagem: 1100212005.bmp
# Dice Coefficient: 0.0028331101143023165
# Jaccard Index (IoU): 0.5654879773691655
# ---
# Imagem: 1100212007.bmp
# Dice Coefficient: 0.002147759171517788
# Jaccard Index (IoU): 0.37710563549480763
# ---
# Imagem: 1100212008.bmp
# Dice Coefficient: 0.002748792966255424
# Jaccard Index (IoU): 0.5395773843517989
# ---
# Imagem: 1100212009.bmp
# Dice Coefficient: 0.002698681975755003
# Jaccard Index (IoU): 0.5245807047238037
# ---
# Imagem: 1100212010.bmp
# Dice Coefficient: 0.0022951224241569567
# Jaccard Index (IoU): 0.4136835416225376
# ---
# Imagem: 1100212012.bmp
# Dice Coefficient: 0.0024233590652535104
# Jaccard Index (IoU): 0.4471325173199938
# ---
# Imagem: 1100212021.bmp
# Dice Coefficient: 0.002376677677092763
# Jaccard Index (IoU): 0.43477458184100726
# ---
# Imagem: 1100212022.bmp
# Dice Coefficient: 0.0027420943392033985
# Jaccard Index (IoU): 0.5375556301956503
# ---
# Imagem: 1100212024.bmp
# Dice Coefficient: 0.0027587764833262554
# Jaccard Index (IoU): 0.5426004580063025
# ---
# Imagem: 1100212025.bmp
# Dice Coefficient: 0.0029956835162908914
# Jaccard Index (IoU): 0.6179911511954395
# ---
# Imagem: 1100212026.bmp
# Dice Coefficient: 0.0028692856953357287
# Jaccard Index (IoU): 0.5768740102058771
# ---
# Imagem: 1100212030.bmp
# Dice Coefficient: 0.002319643931192109
# Jaccard Index (IoU): 0.4199595790647432
# ---
# Imagem: 1100212031.bmp
# Dice Coefficient: 0.0025466313865162345
# Jaccard Index (IoU): 0.48081347397664626
# ---
# Imagem: 1100212032.bmp
# Dice Coefficient: 0.002160423226538781
# Jaccard Index (IoU): 0.38017454613338314
# ---
# Imagem: 1100212034.bmp
# Dice Coefficient: 0.002505557921864198
# Jaccard Index (IoU): 0.4694183946561065
# ---
# Imagem: 1100212039.bmp
# Dice Coefficient: 0.0026480179481405495
# Jaccard Index (IoU): 0.5097126344517579
# ---
# Imagem: 1100212040.bmp
# Dice Coefficient: 0.0025362450248305117
# Jaccard Index (IoU): 0.47791530614827754
# ---
# Imagem: 1100212053.bmp
# Dice Coefficient: 0.0024586384511360356
# Jaccard Index (IoU): 0.45661416981213937
# ---
# Imagem: 1100212057.bmp
# Dice Coefficient: 0.0020394342595375353
# Jaccard Index (IoU): 0.3514022445956464
# ---
# Imagem: 1100212059.bmp
# Dice Coefficient: 0.0028706270199771945
# Jaccard Index (IoU): 0.5772993688007214
# ---
# Imagem: 1100212066.bmp
# Dice Coefficient: 0.0027268263225550928
# Jaccard Index (IoU): 0.5329672802556371
# ---
# Imagem: 1100212072.bmp
# Dice Coefficient: 0.0027066895612914113
# Jaccard Index (IoU): 0.5269574855514211
# ---
# Imagem: 1100212088.bmp
# Dice Coefficient: 0.0024861964546683568
# Jaccard Index (IoU): 0.4641075097488364
# ---
# Imagem: 1100911003.bmp
# Dice Coefficient: 0.002257257777934726
# Jaccard Index (IoU): 0.404100694839959
# ---
# Imagem: 1100911009.bmp
# Dice Coefficient: 0.0025997812748001473
# Jaccard Index (IoU): 0.4958239121406488
# ---
# Imagem: 1100911010.bmp
# Dice Coefficient: 0.0025120335371341313
# Jaccard Index (IoU): 0.4712032761174523
# ---
# Imagem: 1101608119.bmp
# Dice Coefficient: 0.0015126562304044453
# Jaccard Index (IoU): 0.23894807117355085
# ---
# Imagem: 1101609177.bmp
# Dice Coefficient: 0.0018938647068781804
# Jaccard Index (IoU): 0.31833550935690136
# ---
# Imagem: 1101609180.bmp
# Dice Coefficient: 0.0027221722980747174
# Jaccard Index (IoU): 0.5315740921924357
# ---
# Imagem: 1101609185.bmp
# Dice Coefficient: 0.0024565985727464023
# Jaccard Index (IoU): 0.4560625510561326
# ---
# Imagem: 1101609193.bmp
# Dice Coefficient: 0.002284041888328278
# Jaccard Index (IoU): 0.4108657502193624
# ---
# Imagem: 1101609200.bmp
# Dice Coefficient: 0.0022007315149548726
# Jaccard Index (IoU): 0.3900342542497679
# ---
# Imagem: 1101610247.bmp
# Dice Coefficient: 0.002098542403919919
# Jaccard Index (IoU): 0.3653072946582424
# ---
# Imagem: 1101610259.bmp
# Dice Coefficient: 0.0018774595123897731
# Jaccard Index (IoU): 0.31471017936667195
# ---
# Imagem: 1101611266.bmp
# Dice Coefficient: 0.0018868249054007568
# Jaccard Index (IoU): 0.31677736066993933
# ---
# Imagem: 1101611273.bmp
# Dice Coefficient: 0.0018143986683312526
# Jaccard Index (IoU): 0.3009582588923177
# ---
# Imagem: 1105108001.bmp
# Dice Coefficient: 0.0021447639740406017
# Jaccard Index (IoU): 0.3763817967566354
# ---
# Imagem: 1105108002.bmp
# Dice Coefficient: 0.0029807683265152584
# Jaccard Index (IoU): 0.6130280055701687
# ---
# Imagem: 1105110003.bmp
# Dice Coefficient: 0.0021120917029894886
# Jaccard Index (IoU): 0.3685351449151674
# ---
# Imagem: 1105111004.bmp
# Dice Coefficient: 0.0024716383159514273
# Jaccard Index (IoU): 0.460139403180135
# ---
# Imagem: 1105111005.bmp
# Dice Coefficient: 0.00256078431372549
# Jaccard Index (IoU): 0.48478099480326653
# ---
# Imagem: 1105111016.bmp
# Dice Coefficient: 0.0024370485504653146
# Jaccard Index (IoU): 0.45079699644315635
# ---
# Imagem: 1106109086.bmp
# Dice Coefficient: 0.0025110408093686324
# Jaccard Index (IoU): 0.4709293680297398
# ---
# Imagem: 1606511021.bmp
# Dice Coefficient: 0.002136713375698674
# Jaccard Index (IoU): 0.37444000321914317
# ---
# Imagem: 1606511038.bmp
# Dice Coefficient: 0.0024292778591988866
# Jaccard Index (IoU): 0.44871461957933007
# ---
# Imagem: 1606511042.bmp
# Dice Coefficient: 0.0024080177825144817
# Jaccard Index (IoU): 0.44304781058597675
# ---
# Imagem: 1606511043.bmp
# Dice Coefficient: 0.0026447566494659674
# Jaccard Index (IoU): 0.5087654887563102
# ---
# Imagem: 1606511049.bmp
# Dice Coefficient: 0.0021244979185332824
# Jaccard Index (IoU): 0.37150409276944063
# ---
# Imagem: 1802606150.bmp
# Dice Coefficient: 0.0026448592121227055
# Jaccard Index (IoU): 0.5087952568825337
# ---
# Imagem: 1806011012.bmp
# Dice Coefficient: 0.0025713561995555708
# Jaccard Index (IoU): 0.48775853408172626
# ---
# Imagem: 1812710102.bmp
# Dice Coefficient: 0.0022892743165475377
# Jaccard Index (IoU): 0.4121949608691345
# ---
# Imagem: 1816308457.bmp
# Dice Coefficient: 0.0020243519799948042
# Jaccard Index (IoU): 0.34789941273904534
# ---
# Imagem: 1877510560.bmp
# Dice Coefficient: 0.0019598130736386762
# Jaccard Index (IoU): 0.33311322192309645
# ---
# Imagem: 1877510561.bmp
# Dice Coefficient: 0.002816075614942666
# Jaccard Index (IoU): 0.5601832276250881
# ---
# Imagem: 1881310124.bmp
# Dice Coefficient: 0.002690525656620346
# Jaccard Index (IoU): 0.5221673718852844
# ---
# Imagem: 1882909271.bmp
# Dice Coefficient: 0.002381523877315102
# Jaccard Index (IoU): 0.4360476864012932
# ---
# Imagem: 1886008433.bmp
# Dice Coefficient: 0.002728166159391179
# Jaccard Index (IoU): 0.5333688320908768
# ---
# Imagem: 1899212003.bmp
# Dice Coefficient: 0.0026822889302560533
# Jaccard Index (IoU): 0.5197379890911807
# ---
# Imagem: 1900608039.bmp
# Dice Coefficient: 0.0020900201896046342
# Jaccard Index (IoU): 0.36328483600856815
# ---
# Imagem: 1901106043.bmp
# Dice Coefficient: 0.0025309016451052595
# Jaccard Index (IoU): 0.47642872624810345
# ---
# Imagem: 1901111025.bmp
# Dice Coefficient: 0.002716112504626271
# Jaccard Index (IoU): 0.5297638761116222
# ---
# Imagem: 1901205042.bmp
# Dice Coefficient: 0.0003183203756180432
# Jaccard Index (IoU): 0.04230274048188339
# ---
# Imagem: 1901205043.bmp
# Dice Coefficient: 0.0013307384738949352
# Jaccard Index (IoU): 0.2043392179508332
# ---
# Imagem: 1901206003.bmp
# Dice Coefficient: 0.0019048906773159755
# Jaccard Index (IoU): 0.3207833579201676
# ---
# Imagem: 1901206006.bmp
# Dice Coefficient: 0.000550128761553834
# Jaccard Index (IoU): 0.07543234894839357
# ---
# Imagem: 1901206033.bmp
# Dice Coefficient: 0.00030934246553214175
# Jaccard Index (IoU): 0.041060643962405746
# ---
# Imagem: 1901206034.bmp
# Dice Coefficient: 0.0006952017182094358
# Jaccard Index (IoU): 0.0972590917532418
# ---
# Imagem: 1901207007.bmp
# Dice Coefficient: 0.0004207320023736212
# Jaccard Index (IoU): 0.05668405160581938
# ---
# Imagem: 1901207020.bmp
# Dice Coefficient: 0.0005501515743918861
# Jaccard Index (IoU): 0.07543571295664579
# ---
# Imagem: 1901208009.bmp
# Dice Coefficient: 0.0005056890012642225
# Jaccard Index (IoU): 0.06891891891891892
# ---
# Imagem: 1901208012.bmp
# Dice Coefficient: 0.00041002223493417445
# Jaccard Index (IoU): 0.05516156198750055
# ---
# Imagem: 1901208015.bmp
# Dice Coefficient: 0.00017505269021247613
# Jaccard Index (IoU): 0.02282873757268805
# ---
# Imagem: 1901208025.bmp
# Dice Coefficient: 0.0011484372812039948
# Jaccard Index (IoU): 0.1715442492891328
# ---
# Imagem: 1901208029.bmp
# Dice Coefficient: 0.00022645005232368632
# Jaccard Index (IoU): 0.029730780101752403
# ---
# Imagem: 1901208041.bmp
# Dice Coefficient: 0.0013885789647390201
# Jaccard Index (IoU): 0.21513152446934777
# ---
# Imagem: 1901208051.bmp
# Dice Coefficient: 0.0005102554269037342
# Jaccard Index (IoU): 0.06958456973293768
# ---
# Imagem: 1901209007.bmp
# Dice Coefficient: 0.0013068288190600486
# Jaccard Index (IoU): 0.19993377483443708
# ---
# Imagem: 1901209008.bmp
# Dice Coefficient: 0.0006386585606915417
# Jaccard Index (IoU): 0.08864743554655427
# ---
# Imagem: 1901209014.bmp
# Dice Coefficient: 0.000637302770211235
# Jaccard Index (IoU): 0.08844260460953234
# ---
# Imagem: 1901209021.bmp
# Dice Coefficient: 0.0008022222800539377
# Jaccard Index (IoU): 0.11393722022204274
# ---
# Imagem: 1901210017.bmp
# Dice Coefficient: 0.0013150217942361265
# Jaccard Index (IoU): 0.20143972669594926
# ---
# Imagem: 1901210018.bmp
# Dice Coefficient: 0.0009883295384538135
# Jaccard Index (IoU): 0.14418049044356293
# ---
# Imagem: 1901210022.bmp
# Dice Coefficient: 0.002870066244207779
# Jaccard Index (IoU): 0.577121508628358
# ---
# Imagem: 1901211010.bmp
# Dice Coefficient: 0.0005603669723547182
# Jaccard Index (IoU): 0.07694420537986853
# ---
# Imagem: 1901211013.bmp
# Dice Coefficient: 0.0004898153396169644
# Jaccard Index (IoU): 0.06661143701580763
# ---
# Imagem: 1901211018.bmp
# Dice Coefficient: 0.0011915119519856074
# Jaccard Index (IoU): 0.17913094886195685
# ---
# Imagem: 1901211035.bmp
# Dice Coefficient: 0.0009396936423127975
# Jaccard Index (IoU): 0.13611955062530912
# ---
# Imagem: 1901211043.bmp
# Dice Coefficient: 0.00027197755192827567
# Jaccard Index (IoU): 0.035922839115578614
# ---
# Imagem: 1901212002.bmp
# Dice Coefficient: 0.00046787206525088264
# Jaccard Index (IoU): 0.06343799893560405
# ---
# Imagem: 1901212013.bmp
# Dice Coefficient: 0.001285551401106897
# Jaccard Index (IoU): 0.1960403462141348
# ---
# Imagem: 1901212020.bmp
# Dice Coefficient: 0.0008055965819647314
# Jaccard Index (IoU): 0.1144713216454496
# ---
# Imagem: 1901212023.bmp
# Dice Coefficient: 0.0009056989379292865
# Jaccard Index (IoU): 0.1305523590333717
# ---
# Imagem: 1901212024.bmp
# Dice Coefficient: 0.002353704684599564
# Jaccard Index (IoU): 0.4287701241350534
# ---
# Imagem: 1901212033.bmp
# Dice Coefficient: 0.0013820374285490565
# Jaccard Index (IoU): 0.21390126537159151
# ---
# Imagem: 1902310020.bmp
# Dice Coefficient: 0.002076312131198538
# Jaccard Index (IoU): 0.36004423346639336
# ---
# Imagem: 1903304027.bmp
# Dice Coefficient: 0.0026741432553991106
# Jaccard Index (IoU): 0.5173430759749978
# ---
# Imagem: 1903307023.bmp
# Dice Coefficient: 0.0028634787518969592
# Jaccard Index (IoU): 0.5750351655979978
# ---
# Imagem: 1903308003.bmp
# Dice Coefficient: 0.002495360432152889
# Jaccard Index (IoU): 0.46661641180271374
# ---
# Imagem: 1903309054.bmp
# Dice Coefficient: 0.0029428336373927538
# Jaccard Index (IoU): 0.6005410821643287
# ---
# Imagem: 1903309056.bmp
# Dice Coefficient: 0.002668722388764726
# Jaccard Index (IoU): 0.5157534634939235
# ---
# Imagem: 1903310001.bmp
# Dice Coefficient: 0.0020531790133605145
# Jaccard Index (IoU): 0.35461033183788593
# ---
# Imagem: 1903310005.bmp
# Dice Coefficient: 0.002800745286156173
# Jaccard Index (IoU): 0.5554398197355555
# ---
# Imagem: 1903310007.bmp
# Dice Coefficient: 0.002994340762776861
# Jaccard Index (IoU): 0.6175430888138843
# ---
# Imagem: 1903310008.bmp
# Dice Coefficient: 0.0025248830532113124
# Jaccard Index (IoU): 0.4747578730645602
# ---
# Imagem: 1903310028.bmp
# Dice Coefficient: 0.002873297999785575
# Jaccard Index (IoU): 0.5781470692090396
# ---
# Imagem: 1903310029.bmp
# Dice Coefficient: 0.0025400541400875404
# Jaccard Index (IoU): 0.4789768678133246
# ---
# Imagem: 1903310030.bmp
# Dice Coefficient: 0.002622360289942212
# Jaccard Index (IoU): 0.5022931083903198
# ---
# Imagem: 1903310032.bmp
# Dice Coefficient: 0.0030128089435245468
# Jaccard Index (IoU): 0.6237275707384403
# ---
# Imagem: 1903310035.bmp
# Dice Coefficient: 0.00249145492620366
# Jaccard Index (IoU): 0.4655461167497326
# ---
# Imagem: 1903310036.bmp
# Dice Coefficient: 0.0025918160573308296
# Jaccard Index (IoU): 0.4935550425918738
# ---
# Imagem: 1903310039.bmp
# Dice Coefficient: 0.0031116177316190203
# Jaccard Index (IoU): 0.6576360334787419
# ---
# Imagem: 1903310062.bmp
# Dice Coefficient: 0.002630568340333051
# Jaccard Index (IoU): 0.5046587169295209
# ---
# Imagem: 1903311005.bmp
# Dice Coefficient: 0.0020251765403123023
# Jaccard Index (IoU): 0.3480904460619305
# ---
# Imagem: 1903311007.bmp
# Dice Coefficient: 0.0023130808611036397
# Jaccard Index (IoU): 0.41827437125191763
# ---
# Imagem: 1903311008.bmp
# Dice Coefficient: 0.002606799259715324
# Jaccard Index (IoU): 0.4978286852589641
# ---
# Imagem: 1903311009.bmp
# Dice Coefficient: 0.0025844602398347426
# Jaccard Index (IoU): 0.49146586345381527
# ---
# Imagem: 1903311014.bmp
# Dice Coefficient: 0.002399845370787965
# Jaccard Index (IoU): 0.4408812574963702
# ---
# Imagem: 1903311017.bmp
# Dice Coefficient: 0.0028653698685805504
# Jaccard Index (IoU): 0.575633541345143
# ---
# Imagem: 1903311021.bmp
# Dice Coefficient: 0.002255355901185512
# Jaccard Index (IoU): 0.4036227902305929
# ---
# Imagem: 1903312005.bmp
# Dice Coefficient: 0.0021544962812711293
# Jaccard Index (IoU): 0.3787365543471801
# ---
# Imagem: 1903705007.bmp
# Dice Coefficient: 0.002386533030567856
# Jaccard Index (IoU): 0.43736597569692637
# ---
# Imagem: 1903705037.bmp
# Dice Coefficient: 0.0019136286416520506
# Jaccard Index (IoU): 0.32272971783461296
# ---
# Imagem: 1903709070.bmp
# Dice Coefficient: 0.002292400148417917
# Jaccard Index (IoU): 0.4129902217383111
# ---
# Imagem: 1903709071.bmp
# Dice Coefficient: 0.002688663315596199
# Jaccard Index (IoU): 0.521617404075638
# ---
# Imagem: 1903709081.bmp
# Dice Coefficient: 0.002362590169129885
# Jaccard Index (IoU): 0.4310865561694291
# ---
# Imagem: 1903709082.bmp
# Dice Coefficient: 0.002292597213628223
# Jaccard Index (IoU): 0.4130403882469998
# ---
# Imagem: 1903709088.bmp
# Dice Coefficient: 0.0019340783879923651
# Jaccard Index (IoU): 0.3273073481841749
# ---
# Imagem: 1903709091.bmp
# Dice Coefficient: 0.0024762242085869367
# Jaccard Index (IoU): 0.4613870556906333
# ---
# Imagem: 1903709092.bmp
# Dice Coefficient: 0.002284532963265995
# Jaccard Index (IoU): 0.41099039316461733
# ---
# Imagem: 1903709094.bmp
# Dice Coefficient: 0.0019666087859737
# Jaccard Index (IoU): 0.3346548555617502
# ---
# Imagem: 1903709109.bmp
# Dice Coefficient: 0.001947954115805047
# Jaccard Index (IoU): 0.3304314844582513
# ---
# Imagem: 1903709113.bmp
# Dice Coefficient: 0.0025302910624599474
# Jaccard Index (IoU): 0.4762590466216595
# ---
# Imagem: 1903710004.bmp
# Dice Coefficient: 0.002355910973159265
# Jaccard Index (IoU): 0.42934460002095043
# ---
# Imagem: 1903710005.bmp
# Dice Coefficient: 0.0024550706230175873
# Jaccard Index (IoU): 0.45564964035327327
# ---
# Imagem: 1903710008.bmp
# Dice Coefficient: 0.002715229449017142
# Jaccard Index (IoU): 0.5295004418568384
# ---
# Imagem: 1903710012.bmp
# Dice Coefficient: 0.0023075308657655976
# Jaccard Index (IoU): 0.41685241029675274
# ---
# Imagem: 1903710026.bmp
# Dice Coefficient: 0.002654432656619405
# Jaccard Index (IoU): 0.5115790668634351
# ---
# Imagem: 1903710031.bmp
# Dice Coefficient: 0.002533978888084887
# Jaccard Index (IoU): 0.47728447957449954
# ---
# Imagem: 1903710036.bmp
# Dice Coefficient: 0.0029941245800497274
# Jaccard Index (IoU): 0.6174709741588722
# ---
# Imagem: 1903710040.bmp
# Dice Coefficient: 0.002786911837094298
# Jaccard Index (IoU): 0.5511842544201045
# ---
# Imagem: 1903710048.bmp
# Dice Coefficient: 0.0026728817930765504
# Jaccard Index (IoU): 0.5169728677454678
# ---
# Imagem: 1903711002.bmp
# Dice Coefficient: 0.002838607730494091
# Jaccard Index (IoU): 0.5672077098655846
# ---
# Imagem: 1903711012.bmp
# Dice Coefficient: 0.0026345405160474946
# Jaccard Index (IoU): 0.5058061985092193
# ---
# Imagem: 1903711014.bmp
# Dice Coefficient: 0.0028345188565293247
# Jaccard Index (IoU): 0.5659282922113404
# ---
# Imagem: 1903711018.bmp
# Dice Coefficient: 0.002861873084380385
# Jaccard Index (IoU): 0.5745274666050737
# ---
# Imagem: 1903711020.bmp
# Dice Coefficient: 0.002162320815956464
# Jaccard Index (IoU): 0.38063557222733385
# ---
# Imagem: 1903711022.bmp
# Dice Coefficient: 0.002641574660144271
# Jaccard Index (IoU): 0.5078425207853001
# ---
# Imagem: 1903711023.bmp
# Dice Coefficient: 0.0029868576245463433
# Jaccard Index (IoU): 0.615050584376588
# ---
# Imagem: 1903711026.bmp
# Dice Coefficient: 0.0029101158956255217
# Jaccard Index (IoU): 0.5899256629313214
# ---
# Imagem: 1903711032.bmp
# Dice Coefficient: 0.002673588470696562
# Jaccard Index (IoU): 0.5171802380248771
# ---
# Imagem: 1903711035.bmp
# Dice Coefficient: 0.002460154079600523
# Jaccard Index (IoU): 0.4570242929400869
# ---
# Imagem: 1903711036.bmp
# Dice Coefficient: 0.0031586168329498796
# Jaccard Index (IoU): 0.6742668509135575
# ---
# Imagem: 1903711037.bmp
# Dice Coefficient: 0.0029276711958137734
# Jaccard Index (IoU): 0.5956039896564462
# ---
# Imagem: 1903711038.bmp
# Dice Coefficient: 0.0026495121225495913
# Jaccard Index (IoU): 0.5101469696080159
# ---
# Imagem: 1903711046.bmp
# Dice Coefficient: 0.002624339077580609
# Jaccard Index (IoU): 0.5028627259404006
# ---
# Imagem: 1903711047.bmp
# Dice Coefficient: 0.0026452376333514905
# Jaccard Index (IoU): 0.5089051012805915
# ---
# Imagem: 1903711052.bmp
# Dice Coefficient: 0.002948834167401392
# Jaccard Index (IoU): 0.6025033829499323
# ---
# Imagem: 1903711054.bmp
# Dice Coefficient: 0.0029645759464399764
# Jaccard Index (IoU): 0.6076742217624377
# ---
# Imagem: 1903711055.bmp
# Dice Coefficient: 0.0029451261687734936
# Jaccard Index (IoU): 0.6012902210683659
# ---
# Imagem: 1903711057.bmp
# Dice Coefficient: 0.0031019539725566326
# Jaccard Index (IoU): 0.6542573420663427
# ---
# Imagem: 1905008049.bmp
# Dice Coefficient: 0.002758803735284142
# Jaccard Index (IoU): 0.5426087263235865
# ---
# Imagem: 1905008064.bmp
# Dice Coefficient: 0.002492273236636741
# Jaccard Index (IoU): 0.4657702434839206
# ---
# Imagem: 1905009006.bmp
# Dice Coefficient: 0.00232093231128911
# Jaccard Index (IoU): 0.42029086841001256
# ---
# Imagem: 1905010030.bmp
# Dice Coefficient: 0.002700624928266382
# Jaccard Index (IoU): 0.5251567243268488
# ---
# Imagem: 1905010031.bmp
# Dice Coefficient: 0.0025567084283629406
# Jaccard Index (IoU): 0.4836362149675995
# ---
# Imagem: 1905010049.bmp
# Dice Coefficient: 0.0028886183131618345
# Jaccard Index (IoU): 0.5830269996197237
# ---
# Imagem: 1905010050.bmp
# Dice Coefficient: 0.0029844703977254003
# Jaccard Index (IoU): 0.6142570555783523
# ---
# Imagem: 1905010051.bmp
# Dice Coefficient: 0.002621543285016528
# Jaccard Index (IoU): 0.5020580497326657
# ---
# Imagem: 1905011014.bmp
# Dice Coefficient: 0.0027668568894153385
# Jaccard Index (IoU): 0.545055964250332
# ---
# Imagem: 1905012001.bmp
# Dice Coefficient: 0.002314872107243522
# Jaccard Index (IoU): 0.41873391478410066
# ---
# Imagem: 1905012003.bmp
# Dice Coefficient: 0.002370238003190176
# Jaccard Index (IoU): 0.43308635773787096
# ---
# Imagem: 1905012010.bmp
# Dice Coefficient: 0.0025284466871515056
# Jaccard Index (IoU): 0.4757467353779957
# ---
# Imagem: 1905012011.bmp
# Dice Coefficient: 0.002642619279684925
# Jaccard Index (IoU): 0.5081453986464953
# ---
# Imagem: 1905012012.bmp
# Dice Coefficient: 0.002331869561681711
# Jaccard Index (IoU): 0.42310947162851253
# ---
# Imagem: 1905012014.bmp
# Dice Coefficient: 0.002596440099561369
# Jaccard Index (IoU): 0.49487134909596664
# ---
# Imagem: 1905012017.bmp
# Dice Coefficient: 0.0026017352768468345
# Jaccard Index (IoU): 0.49638155740389023
# ---
# Imagem: 1905012022.bmp
# Dice Coefficient: 0.0025712622516124075
# Jaccard Index (IoU): 0.4877320213411712
# ---
# Imagem: 1905012024.bmp
# Dice Coefficient: 0.002270726340146873
# Jaccard Index (IoU): 0.4074944175660588
# ---
# Imagem: 1905012025.bmp
# Dice Coefficient: 0.0025432132759484172
# Jaccard Index (IoU): 0.4798584443942474
# ---
# Imagem: 1905012028.bmp
# Dice Coefficient: 0.0025024779602981517
# Jaccard Index (IoU): 0.4685709801459625
# ---
# Imagem: 1905012030.bmp
# Dice Coefficient: 0.002427154819909322
# Jaccard Index (IoU): 0.4481467303563404
# ---
# Imagem: 1905012031.bmp
# Dice Coefficient: 0.0023252823078462174
# Jaccard Index (IoU): 0.42141055358603763
# ---
# Imagem: 1907107099.bmp
# Dice Coefficient: 0.002245816065144415
# Jaccard Index (IoU): 0.4012305152782728
# ---
# Imagem: 1907707084.bmp
# Dice Coefficient: 0.0026570319776163527
# Jaccard Index (IoU): 0.5123366834170854
# ---
# Imagem: 1910609004.bmp
# Dice Coefficient: 0.0022694630260036027
# Jaccard Index (IoU): 0.4071753986332574
# ---
# Imagem: 1910611084.bmp
# Dice Coefficient: 0.0025270450640251054
# Jaccard Index (IoU): 0.47535764491854793
# ---
# Imagem: 1912210002.bmp
# Dice Coefficient: 0.002532459156229705
# Jaccard Index (IoU): 0.4768617320004493
# ---
# Imagem: 1912211030.bmp
# Dice Coefficient: 0.002936976737843955
# Jaccard Index (IoU): 0.5986303806474564
# ---
# Imagem: 1912212035.bmp
# Dice Coefficient: 0.003036365206875702
# Jaccard Index (IoU): 0.6316848763657275
# ---
# Imagem: 1912212047.bmp
# Dice Coefficient: 0.003029032516265756
# Jaccard Index (IoU): 0.6291995460663482
# ---
# Imagem: 1912410009.bmp
# Dice Coefficient: 0.0024518637430458
# Jaccard Index (IoU): 0.454783779315557
# ---
# Imagem: 1912412005.bmp
# Dice Coefficient: 0.00272441402229442
# Jaccard Index (IoU): 0.5322448388963921
# ---
# Imagem: 1912412009.bmp
# Dice Coefficient: 0.0025617091397231724
# Jaccard Index (IoU): 0.48504099343146184
# ---
# Imagem: 503311001.bmp
# Dice Coefficient: 0.002819195400565417
# Jaccard Index (IoU): 0.5611520758609011
# ---
# Imagem: 516808003.bmp
# Dice Coefficient: 0.0021713153285870188
# Jaccard Index (IoU): 0.3828250175685172
# ---
# Imagem: 516808004.bmp
# Dice Coefficient: 0.002779326680689683
# Jaccard Index (IoU): 0.5488607126900737
# ---
# Imagem: 534010122.bmp
# Dice Coefficient: 0.0025322355176523215
# Jaccard Index (IoU): 0.4767995423247451
# ---
# Imagem: 614410017.bmp
# Dice Coefficient: 0.0026156856556079217
# Jaccard Index (IoU): 0.5003749161371799
# ---

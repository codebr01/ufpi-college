# %% [markdown]
# Conectando com o  drive

# %% [markdown]
# Conectando ao drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Treino_visao
# Out:
# /content/drive/MyDrive/Treino_visao

# %% [markdown]
# Importando YOLO

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt



import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-282-g9cdbd1de Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)

# %% [markdown]
# TREINANDO YOLO

# %%
# !python train.py --img 640 --batch 8 --epochs 300 --data data.yaml --weights yolov5s.pt --cache --sync-bn
# Out:
# 2024-02-06 17:52:29.127805: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-06 17:52:29.127855: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-06 17:52:29.129321: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# **VALIDANDO** IMAGENS

# %%
# !python val.py --data data.yaml --weights runs/train/exp/weights/best.pt --imgsz 640 --half
# Out:
# val: data=data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v7.0-282-g9cdbd1de Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/MyDrive/Treino_visao/Train_data/labels/val.cache... 30 images, 1 backgrounds, 0 corrupt: 100% 31/31 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.96s/it]
#                    all         31        216      0.538      0.347      0.309      0.137
# Speed: 0.1ms pre-process, 10.4ms inference, 41.2ms NMS per image at shape (32, 3, 640, 640)
# ...

# %% [markdown]
# DETECTANDO

# %%
# !python detect.py --weights runs/train/exp12/weights/best.pt --img 640 --conf 0.25 --source ../base/
# Out:
# detect: weights=['runs/train/exp12/weights/best.pt'], source=../base/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-282-g9cdbd1de Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/25 /content/drive/MyDrive/Treino_visao/base/765254_ES_259_259ES000000_00370_RAW.jpg: 416x640 4 Crackeds, 50.1ms
# image 2/25 /content/drive/MyDrive/Treino_visao/base/766172_ES_259_259ES000000_04960_RAW.jpg: 416x640 3 Crackeds, 8.5ms
# ...

# %% [markdown]
# Extraindo Acurácia

# %%
import pandas as pd

# Carregue o relatório gerado pelo YOLOv5
df = pd.read_csv('/content/drive/MyDrive/Treino_visao/yolov5/runs/train/exp11/results.csv')

# A coluna 'mAP_0.5' contém a mAP
map_0_5_095 = df.loc[:, df.columns.str.contains('metrics/precision')].iloc[-1].values[0]  # Obter o valor da última época

# Corrigir o nome da variável na impressão
print(f'Acurácia (mAP 0.5:0.95): {map_0_5_095:.2%}')
# Out:
# Acurácia (mAP 0.5:0.95): 55.21%

# %% [markdown]
# Outra forma de extrair acuracia

# %%
# !pip install tensorboardX
# %load_ext tensorboard
# %tensorboard --logdir=/content/drive/MyDrive/Treino_visao/yolov5/
